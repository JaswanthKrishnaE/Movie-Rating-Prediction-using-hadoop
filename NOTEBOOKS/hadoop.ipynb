# %%
# !wget -qq https://downloads.apache.org/hadoop/common/hadoop-3.3.3/hadoop-3.3.3.tar.gz

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,OneHotEncoder,OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from catboost import CatBoostRegressor
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split


def preprocess_movie_data(data_path):
    data = pd.read_csv(data_path)
    no_genre = data[pd.isnull(data['genres'])]
    i = data[pd.isnull(data['genres'])].index
    listgenre = ['Science Fiction & Fantasy','Drama','Animation','Animation','Animation','Action & Adventure','Musical & Performing Arts','Romance','Action & Adventure','Drama','Comedy','Animation','Action & Adventure','Horror','Action & Adventure','Mystery & Suspense','Science Fiction & Fantasy','Documentary','Animation']
    for g in range(0, len(no_genre)):
        data.loc[i[g], 'genres'] = listgenre[g]
    df = data['genres'].str.get_dummies(',')
    data = pd.concat([data, df], axis=1)
    drop_column = ["movie_title","rotten_tomatoes_link","movie_info","original_release_date","streaming_release_date","critics_consensus","genres","directors","authors","actors","production_company"]
    data.drop(drop_column, axis=1, inplace=True)
    cont_col = list(data.describe())
    cat_col = [c for c in data.columns if c not in cont_col]
    cont_data = data[cont_col]
    cat_data = data[cat_col]
    imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
    cont_data = imputer.fit_transform(cont_data)
    cont_data = pd.DataFrame(cont_data, columns=cont_col)
    imputer2 = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
    cat_data = imputer2.fit_transform(cat_data)
    cat_data = pd.DataFrame(cat_data, columns=cat_col)
    oe = OrdinalEncoder(categories=[['Rotten','Fresh','Certified-Fresh']])
    cat_data['tomatometer_status'] = oe.fit_transform(cat_data[['tomatometer_status']])
    final_data = pd.concat([cat_data, cont_data], axis=1)
    column_name = 'tomatometer_rating'
    column = final_data.pop(column_name)
    final_data[column_name] = column
    final_data.to_csv('bda.csv', index=False)
    return final_data

data_path = '/kaggle/input/rotten-tomatoes-movies-and-critic-reviews-dataset/rotten_tomatoes_movies.csv'
preprocessed_data = preprocess_movie_data(data_path)
preprocessed_data.sample(5)
# Out:
#       content_rating  tomatometer_status audience_status     runtime  \
# 10799          PG-13                 0.0         Upright  100.000000
# 14873              R                 0.0         Upright  109.000000
# 11678             NR                 1.0         Upright  102.214048
# 10539             NR                 1.0         Upright   96.000000
# 10081             PG                 0.0         Upright  117.000000
#
#        tomatometer_count  audience_rating  audience_count  \
# 10799               10.0             65.0          1889.0
# 14873               14.0             65.0           106.0
# 11678                5.0             85.0            47.0
# 10539               15.0             83.0          2850.0
# 10081               77.0             76.0          6179.0
#
#        tomatometer_top_critics_count  tomatometer_fresh_critics_count  \
# 10799                            6.0                              3.0
# 14873                           10.0                              6.0
# 11678                            3.0                              5.0
# 10539                            5.0                             15.0
# 10081                           26.0                             43.0
#
#        tomatometer_rotten_critics_count  ...  Horror  Kids & Family  \
# 10799                               7.0  ...     0.0            0.0
# 14873                               8.0  ...     0.0            0.0
# 11678                               0.0  ...     0.0            0.0
# 10539                               0.0  ...     0.0            0.0
# 10081                              34.0  ...     0.0            0.0
#
#        Musical & Performing Arts  Mystery & Suspense  Romance  \
# 10799                        0.0                 0.0      0.0
# 14873                        0.0                 0.0      0.0
# 11678                        0.0                 0.0      0.0
# 10539                        0.0                 0.0      0.0
# 10081                        0.0                 0.0      0.0
#
#        Science Fiction & Fantasy  Special Interest  Television  Western  \
# 10799                        0.0               0.0         0.0      0.0
# 14873                        0.0               0.0         0.0      0.0
# 11678                        0.0               0.0         0.0      0.0
# 10539                        0.0               0.0         0.0      0.0
# 10081                        0.0               0.0         0.0      0.0
#
#        tomatometer_rating
# 10799                30.0
# 14873                43.0
# 11678               100.0
# 10539               100.0
# 10081                56.0
#
# [5 rows x 48 columns]

# %%
preprocessed_data.columns
# Out:
# Index(['content_rating', 'tomatometer_status', 'audience_status', 'runtime',
#        'tomatometer_count', 'audience_rating', 'audience_count',
#        'tomatometer_top_critics_count', 'tomatometer_fresh_critics_count',
#        'tomatometer_rotten_critics_count', ' Animation', ' Anime & Manga',
#        ' Art House & International', ' Classics', ' Comedy', ' Cult Movies',
#        ' Documentary', ' Drama', ' Faith & Spirituality', ' Gay & Lesbian',
#        ' Horror', ' Kids & Family', ' Musical & Performing Arts',
#        ' Mystery & Suspense', ' Romance', ' Science Fiction & Fantasy',
#        ' Special Interest', ' Sports & Fitness', ' Television', ' Western',
#        'Action & Adventure', 'Animation', 'Art House & International',
#        'Classics', 'Comedy', 'Cult Movies', 'Documentary', 'Drama', 'Horror',
#        'Kids & Family', 'Musical & Performing Arts', 'Mystery & Suspense',
#        'Romance', 'Science Fiction & Fantasy', 'Special Interest',
#        'Television', 'Western', 'tomatometer_rating'],
#       dtype='object')

# %%
# !tar -xzvf hadoop-3.3.3.tar.gz
# Out:
# hadoop-3.3.3/
# hadoop-3.3.3/licenses-binary/
# hadoop-3.3.3/licenses-binary/LICENSE-dust.txt
# hadoop-3.3.3/licenses-binary/LICENSE-re2j.txt
# hadoop-3.3.3/licenses-binary/LICENSE-slf4j.txt
# hadoop-3.3.3/licenses-binary/LICENSE-jquery.txt
# hadoop-3.3.3/licenses-binary/LICENSE-zstd-jni.txt
# hadoop-3.3.3/licenses-binary/LICENSE-hsql.txt
# hadoop-3.3.3/licenses-binary/LICENSE-datatables.txt
# hadoop-3.3.3/licenses-binary/LICENSE-jaf.txt
# hadoop-3.3.3/licenses-binary/LICENSE-hamcrest.txt
# hadoop-3.3.3/licenses-binary/LICENSE-ojalgo.txt
# hadoop-3.3.3/licenses-binary/LICENSE-mssql-jdbc.txt
# hadoop-3.3.3/licenses-binary/LICENSE-jdom.txt
# hadoop-3.3.3/licenses-binary/LICENSE-jsr305.txt
# hadoop-3.3.3/licenses-binary/LICENSE-nvd3.txt
# hadoop-3.3.3/licenses-binary/LICENSE-angular-nvd3.txt
# hadoop-3.3.3/licenses-binary/LICENSE-bloomfilter.txt
# hadoop-3.3.3/licenses-binary/LICENSE-azure-keyvault.txt
# hadoop-3.3.3/licenses-binary/LICENSE-xtermjs.txt
# hadoop-3.3.3/licenses-binary/LICENSE-leveldb.txt
# hadoop-3.3.3/licenses-binary/LICENSE-jline.txt
# hadoop-3.3.3/licenses-binary/LICENSE-protobuf.txt
# hadoop-3.3.3/licenses-binary/LICENSE-moment.txt
# hadoop-3.3.3/licenses-binary/LICENSE-gtest.txt
# hadoop-3.3.3/licenses-binary/LICENSE-jstree.txt
# hadoop-3.3.3/licenses-binary/LICENSE-azure-cosmosdb.txt
# hadoop-3.3.3/licenses-binary/LICENSE-go.txt
# hadoop-3.3.3/licenses-binary/LICENSE-checker-framework.txt
# hadoop-3.3.3/licenses-binary/LICENSE-jsch.txt
# hadoop-3.3.3/licenses-binary/LICENSE-jakarta.xml.bind-api.txt
# hadoop-3.3.3/licenses-binary/LICENSE-d3.txt
# hadoop-3.3.3/licenses-binary/LICENSE-junit.txt
# hadoop-3.3.3/licenses-binary/LICENSE-freebsd.txt
# hadoop-3.3.3/licenses-binary/LICENSE-cddl-gplv2-ce.txt
# hadoop-3.3.3/licenses-binary/LICENSE-bouncycastle.txt
# hadoop-3.3.3/licenses-binary/LICENSE-dnsjava.txt
# hadoop-3.3.3/licenses-binary/LICENSE-leveldbjni.txt
# hadoop-3.3.3/licenses-binary/LICENSE-angular.txt
# hadoop-3.3.3/licenses-binary/LICENSE-asm.txt
# hadoop-3.3.3/licenses-binary/LICENSE-tree.txt
# hadoop-3.3.3/licenses-binary/LICENSE-lz4.txt
# hadoop-3.3.3/licenses-binary/LICENSE-slicing-by-8.txt
# hadoop-3.3.3/licenses-binary/LICENSE-azure-data-lake-store.txt
# hadoop-3.3.3/licenses-binary/LICENSE-paranamer.txt
# hadoop-3.3.3/lib/
# hadoop-3.3.3/lib/native/
# hadoop-3.3.3/lib/native/libhdfspp.so.0.1.0
# hadoop-3.3.3/lib/native/libhdfs.so.0.0.0
# hadoop-3.3.3/lib/native/examples/
# hadoop-3.3.3/lib/native/examples/wordcount-simple
# hadoop-3.3.3/lib/native/examples/pipes-sort
# hadoop-3.3.3/lib/native/examples/wordcount-part
# hadoop-3.3.3/lib/native/examples/wordcount-nopipe
# hadoop-3.3.3/lib/native/libhadooputils.a
# hadoop-3.3.3/lib/native/libhdfspp.so
# hadoop-3.3.3/lib/native/libnativetask.a
# hadoop-3.3.3/lib/native/libhdfs.a
# hadoop-3.3.3/lib/native/libhadoop.so.1.0.0
# hadoop-3.3.3/lib/native/libhdfspp.a
# hadoop-3.3.3/lib/native/libhadoop.so
# hadoop-3.3.3/lib/native/libhadoop.a
# hadoop-3.3.3/lib/native/libnativetask.so.1.0.0
# hadoop-3.3.3/lib/native/libnativetask.so
# hadoop-3.3.3/lib/native/libhdfs.so
# hadoop-3.3.3/lib/native/libhadooppipes.a
# hadoop-3.3.3/etc/
# hadoop-3.3.3/etc/hadoop/
# hadoop-3.3.3/etc/hadoop/user_ec_policies.xml.template
# hadoop-3.3.3/etc/hadoop/hdfs-rbf-site.xml
# hadoop-3.3.3/etc/hadoop/yarn-env.cmd
# hadoop-3.3.3/etc/hadoop/yarnservice-log4j.properties
# hadoop-3.3.3/etc/hadoop/shellprofile.d/
# hadoop-3.3.3/etc/hadoop/shellprofile.d/example.sh
# hadoop-3.3.3/etc/hadoop/yarn-env.sh
# hadoop-3.3.3/etc/hadoop/mapred-env.cmd
# hadoop-3.3.3/etc/hadoop/mapred-site.xml
# hadoop-3.3.3/etc/hadoop/capacity-scheduler.xml
# hadoop-3.3.3/etc/hadoop/httpfs-log4j.properties
# hadoop-3.3.3/etc/hadoop/configuration.xsl
# hadoop-3.3.3/etc/hadoop/hdfs-site.xml
# hadoop-3.3.3/etc/hadoop/ssl-server.xml.example
# hadoop-3.3.3/etc/hadoop/httpfs-site.xml
# hadoop-3.3.3/etc/hadoop/kms-log4j.properties
# hadoop-3.3.3/etc/hadoop/kms-env.sh
# hadoop-3.3.3/etc/hadoop/hadoop-metrics2.properties
# hadoop-3.3.3/etc/hadoop/yarn-site.xml
# hadoop-3.3.3/etc/hadoop/ssl-client.xml.example
# hadoop-3.3.3/etc/hadoop/hadoop-env.sh
# hadoop-3.3.3/etc/hadoop/log4j.properties
# hadoop-3.3.3/etc/hadoop/core-site.xml
# hadoop-3.3.3/etc/hadoop/kms-acls.xml
# hadoop-3.3.3/etc/hadoop/kms-site.xml
# hadoop-3.3.3/etc/hadoop/hadoop-policy.xml
# hadoop-3.3.3/etc/hadoop/hadoop-user-functions.sh.example
# hadoop-3.3.3/etc/hadoop/mapred-queues.xml.template
# hadoop-3.3.3/etc/hadoop/container-executor.cfg
# hadoop-3.3.3/etc/hadoop/hadoop-env.cmd
# hadoop-3.3.3/etc/hadoop/mapred-env.sh
# hadoop-3.3.3/etc/hadoop/workers
# hadoop-3.3.3/etc/hadoop/httpfs-env.sh
# hadoop-3.3.3/include/
# hadoop-3.3.3/include/Pipes.hh
# hadoop-3.3.3/include/StringUtils.hh
# hadoop-3.3.3/include/hdfs.h
# hadoop-3.3.3/include/SerialUtils.hh
# hadoop-3.3.3/include/TemplateFactory.hh
# hadoop-3.3.3/NOTICE-binary
# hadoop-3.3.3/LICENSE.txt
# hadoop-3.3.3/libexec/
# hadoop-3.3.3/libexec/shellprofile.d/
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-aliyun.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-s3guard.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-httpfs.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-distcp.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-rumen.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-archive-logs.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-azure-datalake.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-aws.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-kafka.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-yarn.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-extras.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-hdfs.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-azure.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-kms.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-archives.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-gridmix.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-mapreduce.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-streaming.sh
# hadoop-3.3.3/libexec/shellprofile.d/hadoop-openstack.sh
# hadoop-3.3.3/libexec/hadoop-functions.sh
# hadoop-3.3.3/libexec/yarn-config.cmd
# hadoop-3.3.3/libexec/mapred-config.sh
# hadoop-3.3.3/libexec/hadoop-config.sh
# hadoop-3.3.3/libexec/hadoop-layout.sh.example
# hadoop-3.3.3/libexec/mapred-config.cmd
# hadoop-3.3.3/libexec/hadoop-config.cmd
# hadoop-3.3.3/libexec/yarn-config.sh
# hadoop-3.3.3/libexec/hdfs-config.cmd
# hadoop-3.3.3/libexec/hdfs-config.sh
# hadoop-3.3.3/libexec/tools/
# hadoop-3.3.3/libexec/tools/hadoop-sls.sh
# hadoop-3.3.3/libexec/tools/hadoop-dynamometer-infra.sh
# hadoop-3.3.3/libexec/tools/hadoop-resourceestimator.sh
# hadoop-3.3.3/libexec/tools/hadoop-distcp.sh
# hadoop-3.3.3/libexec/tools/hadoop-rumen.sh
# hadoop-3.3.3/libexec/tools/hadoop-archive-logs.sh
# hadoop-3.3.3/libexec/tools/hadoop-dynamometer-workload.sh
# hadoop-3.3.3/libexec/tools/hadoop-dynamometer-blockgen.sh
# hadoop-3.3.3/libexec/tools/hadoop-aws.sh
# hadoop-3.3.3/libexec/tools/hadoop-extras.sh
# hadoop-3.3.3/libexec/tools/hadoop-archives.sh
# hadoop-3.3.3/libexec/tools/hadoop-gridmix.sh
# hadoop-3.3.3/libexec/tools/hadoop-streaming.sh
# hadoop-3.3.3/LICENSE-binary
# hadoop-3.3.3/NOTICE.txt
# hadoop-3.3.3/README.txt
# hadoop-3.3.3/sbin/
# hadoop-3.3.3/sbin/httpfs.sh
# hadoop-3.3.3/sbin/distribute-exclude.sh
# hadoop-3.3.3/sbin/start-secure-dns.sh
# hadoop-3.3.3/sbin/refresh-namenodes.sh
# hadoop-3.3.3/sbin/workers.sh
# hadoop-3.3.3/sbin/FederationStateStore/
# hadoop-3.3.3/sbin/FederationStateStore/MySQL/
# hadoop-3.3.3/sbin/FederationStateStore/MySQL/FederationStateStoreDatabase.sql
# hadoop-3.3.3/sbin/FederationStateStore/MySQL/dropTables.sql
# hadoop-3.3.3/sbin/FederationStateStore/MySQL/FederationStateStoreUser.sql
# hadoop-3.3.3/sbin/FederationStateStore/MySQL/dropUser.sql
# hadoop-3.3.3/sbin/FederationStateStore/MySQL/dropStoreProcedures.sql
# hadoop-3.3.3/sbin/FederationStateStore/MySQL/dropDatabase.sql
# hadoop-3.3.3/sbin/FederationStateStore/MySQL/FederationStateStoreStoredProcs.sql
# hadoop-3.3.3/sbin/FederationStateStore/MySQL/FederationStateStoreTables.sql
# hadoop-3.3.3/sbin/FederationStateStore/SQLServer/
# hadoop-3.3.3/sbin/FederationStateStore/SQLServer/FederationStateStoreStoreProcs.sql
# hadoop-3.3.3/sbin/FederationStateStore/SQLServer/FederationStateStoreTables.sql
# hadoop-3.3.3/sbin/stop-yarn.cmd
# hadoop-3.3.3/sbin/stop-dfs.cmd
# hadoop-3.3.3/sbin/stop-dfs.sh
# hadoop-3.3.3/sbin/hadoop-daemons.sh
# hadoop-3.3.3/sbin/yarn-daemon.sh
# hadoop-3.3.3/sbin/start-all.sh
# hadoop-3.3.3/sbin/stop-all.sh
# hadoop-3.3.3/sbin/yarn-daemons.sh
# hadoop-3.3.3/sbin/stop-secure-dns.sh
# hadoop-3.3.3/sbin/start-dfs.cmd
# hadoop-3.3.3/sbin/start-yarn.cmd
# hadoop-3.3.3/sbin/stop-all.cmd
# hadoop-3.3.3/sbin/stop-yarn.sh
# hadoop-3.3.3/sbin/start-yarn.sh
# hadoop-3.3.3/sbin/kms.sh
# hadoop-3.3.3/sbin/mr-jobhistory-daemon.sh
# hadoop-3.3.3/sbin/start-dfs.sh
# hadoop-3.3.3/sbin/start-all.cmd
# hadoop-3.3.3/sbin/stop-balancer.sh
# hadoop-3.3.3/sbin/start-balancer.sh
# hadoop-3.3.3/sbin/hadoop-daemon.sh
# hadoop-3.3.3/bin/
# hadoop-3.3.3/bin/oom-listener
# hadoop-3.3.3/bin/hdfs
# hadoop-3.3.3/bin/container-executor
# hadoop-3.3.3/bin/yarn
# hadoop-3.3.3/bin/mapred
# hadoop-3.3.3/bin/hadoop
# hadoop-3.3.3/bin/mapred.cmd
# hadoop-3.3.3/bin/yarn.cmd
# hadoop-3.3.3/bin/hdfs.cmd
# hadoop-3.3.3/bin/test-container-executor
# hadoop-3.3.3/bin/hadoop.cmd
# hadoop-3.3.3/share/
# hadoop-3.3.3/share/hadoop/
# hadoop-3.3.3/share/hadoop/hdfs/
# hadoop-3.3.3/share/hadoop/hdfs/hadoop-hdfs
html
# hadoop-3.3.3/share/hadoop/hdfs/webapps/hdfs/WEB-INF/
# hadoop-3.3.3/share/hadoop/hdfs/webapps/hdfs/WEB-INF/web.xml
# hadoop-3.3.3/share/hadoop/hdfs/webapps/hdfs/explorer.html
# hadoop-3.3.3/share/hadoop/hdfs/webapps/router/
# hadoop-3.3.3/share/hadoop/hdfs/webapps/router/robots.txt
# hadoop-3.3.3/share/hadoop/hdfs/webapps/router/federationhealth.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/router/index.html
# hadoop-3.3.3/share/hadoop/hdfs/webapps/router/federationhealth.html
# hadoop-3.3.3/share/hadoop/hdfs/webapps/router/explorer.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/router/WEB-INF/
# hadoop-3.3.3/share/hadoop/hdfs/webapps/router/WEB-INF/web.xml
# hadoop-3.3.3/share/hadoop/hdfs/webapps/router/explorer.html
# hadoop-3.3.3/share/hadoop/hdfs/webapps/journal/
# hadoop-3.3.3/share/hadoop/hdfs/webapps/journal/robots.txt
# hadoop-3.3.3/share/hadoop/hdfs/webapps/journal/index.html
# hadoop-3.3.3/share/hadoop/hdfs/webapps/journal/journalnode.html
# hadoop-3.3.3/share/hadoop/hdfs/webapps/journal/WEB-INF/
# hadoop-3.3.3/share/hadoop/hdfs/webapps/journal/WEB-INF/web.xml
# hadoop-3.3.3/share/hadoop/hdfs/webapps/journal/jn.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/datanode/
# hadoop-3.3.3/share/hadoop/hdfs/webapps/datanode/robots.txt
# hadoop-3.3.3/share/hadoop/hdfs/webapps/datanode/index.html
# hadoop-3.3.3/share/hadoop/hdfs/webapps/datanode/datanode.html
# hadoop-3.3.3/share/hadoop/hdfs/webapps/datanode/dn.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/datanode/WEB-INF/
# hadoop-3.3.3/share/hadoop/hdfs/webapps/datanode/WEB-INF/web.xml
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/jquery-3.5.1.min.js.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/json-bignum.js.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/hadoop.css
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/dust-helpers-1.1.1.min.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/dataTables.bootstrap.js.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/json-bignum.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/rest-csrf.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/jquery.dataTables.min.js.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/dust-full-2.0.0.min.js.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/dfs-dust.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/d3-v4.1.1.min.js.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/jquery-3.5.1.min.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/dust-helpers-1.1.1.min.js.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/dataTables.bootstrap.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/moment.min.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/dataTables.bootstrap.css
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/jquery.dataTables.min.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/moment.min.js.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/fonts/
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/fonts/glyphicons-halflings-regular.woff
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/fonts/glyphicons-halflings-regular.eot
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/fonts/glyphicons-halflings-regular.woff2
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/fonts/glyphicons-halflings-regular.svg
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/fonts/glyphicons-halflings-regular.ttf
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/js/
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/js/bootstrap-editable.min.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/js/bootstrap.js.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/js/bootstrap.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/js/npm.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/js/bootstrap-editable.min.js.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/js/npm.js.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/js/bootstrap.min.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/js/bootstrap.min.js.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/css/
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/css/bootstrap-theme.css.map
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/css/bootstrap-theme.css
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/css/bootstrap-editable.css.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/css/bootstrap.css.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/css/bootstrap-editable.css
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/css/bootstrap-theme.min.css
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/css/bootstrap-theme.min.css.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/css/bootstrap.min.css
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/css/bootstrap.css.map
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/css/bootstrap-theme.min.css.map
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/css/bootstrap.min.css.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/css/bootstrap-theme.css.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/css/bootstrap.min.css.map
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/bootstrap-3.4.1/css/bootstrap.css
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/d3-v4.1.1.min.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/dataTables.bootstrap.css.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/dfs-dust.js.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/hadoop.css.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/dust-full-2.0.0.min.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/rbf.css
# hadoop-3.3.3/share/hadoop/hdfs/webapps/static/rest-csrf.js.gz
# hadoop-3.3.3/share/hadoop/hdfs/webapps/secondary/
# hadoop-3.3.3/share/hadoop/hdfs/webapps/secondary/robots.txt
# hadoop-3.3.3/share/hadoop/hdfs/webapps/secondary/index.html
# hadoop-3.3.3/share/hadoop/hdfs/webapps/secondary/status.html
# hadoop-3.3.3/share/hadoop/hdfs/webapps/secondary/snn.js
# hadoop-3.3.3/share/hadoop/hdfs/webapps/secondary/WEB-INF/
# hadoop-3.3.3/share/hadoop/hdfs/webapps/secondary/WEB-INF/web.xml
# hadoop-3.3.3/share/hadoop/hdfs/webapps/nfs3/
# hadoop-3.3.3/share/hadoop/hdfs/webapps/nfs3/WEB-INF/
# hadoop-3.3.3/share/hadoop/hdfs/webapps/nfs3/WEB-INF/web.xml
# hadoop-3.3.3/share/hadoop/hdfs/hadoop-hdfs-nfs-3.3.3.jar
# hadoop-3.3.3/share/hadoop/hdfs/sources/
# hadoop-3.3.3/share/hadoop/hdfs/sources/hadoop-hdfs-rbf-3.3.3-test-sources.jar
# hadoop-3.3.3/share/hadoop/hdfs/sources/hadoop-hdfs-native-client-3.3.3-sources.jar
# hadoop-3.3.3/share/hadoop/hdfs/sources/hadoop-hdfs-native-client-3.3.3-test-sources.jar
# hadoop-3.3.3/share/hadoop/hdfs/sources/hadoop-hdfs-client-3.3.3-sources.jar
# hadoop-3.3.3/share/hadoop/hdfs/sources/hadoop-hdfs-rbf-3.3.3-sources.jar
# hadoop-3.3.3/share/hadoop/hdfs/sources/hadoop-hdfs-client-3.3.3-test-sources.jar
# hadoop-3.3.3/share/hadoop/hdfs/sources/hadoop-hdfs-3.3.3-sources.jar
# hadoop-3.3.3/share/hadoop/hdfs/sources/hadoop-hdfs-3.3.3-test-sources.jar
# hadoop-3.3.3/share/hadoop/hdfs/hadoop-hdfs-3.3.3.jar
# hadoop-3.3.3/share/hadoop/hdfs/hadoop-hdfs-native-client-3.3.3.jar
# hadoop-3.3.3/share/hadoop/mapreduce/
# hadoop-3.3.3/share/hadoop/mapreduce/hadoop-mapreduce-client
1.jar
# hadoop-3.3.3/share/hadoop/common/lib/jersey-json-1.19.jar
# hadoop-3.3.3/share/hadoop/common/lib/avro-1.7.7.jar
# hadoop-3.3.3/share/hadoop/common/lib/kerb-client-1.0.1.jar
# hadoop-3.3.3/share/hadoop/common/lib/kerby-xdr-1.0.1.jar
# ...
# hadoop-3.3.3/share/doc/hadoop/hadoop-client-runtime/images/external.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-client-runtime/images/icon_info_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-client-runtime/images/logo_apache.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-client-runtime/images/bg.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-client-runtime/images/newwindow.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-client-runtime/images/h3.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/index.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/project-reports.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/dependency-analysis.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/troubleshooting_adl.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/css/
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/css/maven-base.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/css/print.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/css/maven-theme.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/css/site.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/breadcrumbs.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/apache-maven-project-2.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/maven-logo-2.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/collapsed.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/logo_maven.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/icon_warning_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/logos/
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/logos/build-by-maven-black.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/logos/maven-feather.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/logos/build-by-maven-white.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/banner.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/h5.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/icon_error_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/icon_success_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/expanded.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/external.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/icon_info_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/logo_apache.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/bg.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/newwindow.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-azure-datalake/images/h3.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/project-reports.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/dependency-analysis.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/css/
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/css/maven-base.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/css/print.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/css/maven-theme.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/css/site.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/breadcrumbs.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/apache-maven-project-2.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/maven-logo-2.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/collapsed.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/logo_maven.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/icon_warning_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/logos/
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/logos/build-by-maven-black.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/logos/maven-feather.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/logos/build-by-maven-white.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/banner.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/h5.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/icon_error_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/icon_success_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/expanded.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/external.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/icon_info_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/logo_apache.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/bg.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/newwindow.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/images/h3.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/directory_markers.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/s3_select.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/committer_architecture.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/index.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/committers.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/auditing_architecture.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/s3guard.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/testing.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/auditing.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/audit-architecture.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/troubleshooting_s3a.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/assumed_roles.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/performance.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/delegation_token_architecture.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/s3n.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/delegation_tokens.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-aws/tools/hadoop-aws/encryption.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/project-reports.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/dependency-analysis.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/css/
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/css/maven-base.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/css/print.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/css/maven-theme.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/css/site.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/HadoopStreaming.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/breadcrumbs.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/apache-maven-project-2.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/maven-logo-2.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/collapsed.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/logo_maven.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/icon_warning_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/logos/
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/logos/build-by-maven-black.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/logos/maven-feather.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/logos/build-by-maven-white.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/banner.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/h5.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/icon_error_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/icon_success_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/expanded.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/external.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/icon_info_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/logo_apache.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/bg.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/newwindow.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-streaming/images/h3.jpg
# hadoop-3.3.3/share/doc/hadoop/images/
# hadoop-3.3.3/share/doc/hadoop/images/breadcrumbs.jpg
# hadoop-3.3.3/share/doc/hadoop/images/apache-maven-project-2.png
# hadoop-3.3.3/share/doc/hadoop/images/maven-logo-2.gif
# hadoop-3.3.3/share/doc/hadoop/images/collapsed.gif
# hadoop-3.3.3/share/doc/hadoop/images/logo_maven.jpg
# hadoop-3.3.3/share/doc/hadoop/images/icon_warning_sml.gif
# hadoop-3.3.3/share/doc/hadoop/images/logos/
# hadoop-3.3.3/share/doc/hadoop/images/logos/build-by-maven-black.png
# hadoop-3.3.3/share/doc/hadoop/images/logos/maven-feather.png
# hadoop-3.3.3/share/doc/hadoop/images/logos/build-by-maven-white.png
# hadoop-3.3.3/share/doc/hadoop/images/banner.jpg
# hadoop-3.3.3/share/doc/hadoop/images/h5.jpg
# hadoop-3.3.3/share/doc/hadoop/images/icon_error_sml.gif
# hadoop-3.3.3/share/doc/hadoop/images/icon_success_sml.gif
# hadoop-3.3.3/share/doc/hadoop/images/expanded.gif
# hadoop-3.3.3/share/doc/hadoop/images/external.png
# hadoop-3.3.3/share/doc/hadoop/images/icon_info_sml.gif
# hadoop-3.3.3/share/doc/hadoop/images/logo_apache.jpg
# hadoop-3.3.3/share/doc/hadoop/images/bg.jpg
# hadoop-3.3.3/share/doc/hadoop/images/newwindow.png
# hadoop-3.3.3/share/doc/hadoop/images/h3.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/SchedulerLoadSimulator.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/project-reports.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/dependency-analysis.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/css/
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/css/maven-base.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/css/print.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/css/maven-theme.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/css/site.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/breadcrumbs.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/apache-maven-project-2.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/sls_queue_allocated_memory.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/maven-logo-2.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/collapsed.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/logo_maven.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/icon_warning_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/sls_queue_allocated_vcores.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/sls_arch.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/logos/
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/logos/build-by-maven-black.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/logos/maven-feather.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/logos/build-by-maven-white.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/sls_cluster_memory.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/sls_scheduler_operation_timecost.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/banner.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/sls_cluster_vcores.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/h5.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/icon_error_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/icon_success_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/expanded.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/external.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/sls_JVM.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/sls_track_job.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/icon_info_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/logo_apache.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/bg.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/newwindow.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/sls_track_queue.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/sls_running_apps_containers.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-sls/images/h3.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/project-reports.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/dependency-analysis.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/css/
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/css/maven-base.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/css/print.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/css/maven-theme.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/css/site.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/HadoopArchives.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/breadcrumbs.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/apache-maven-project-2.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/maven-logo-2.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/collapsed.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/logo_maven.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/icon_warning_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/logos/
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/logos/build-by-maven-black.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/logos/maven-feather.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/logos/build-by-maven-white.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/banner.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/h5.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/icon_error_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/icon_success_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/expanded.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/external.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/icon_info_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/logo_apache.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/bg.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/newwindow.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-archives/images/h3.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/project-reports.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/dependency-analysis.html
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/css/
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/css/maven-base.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/css/print.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/css/maven-theme.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/css/site.css
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/breadcrumbs.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/apache-maven-project-2.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/maven-logo-2.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/collapsed.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/logo_maven.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/icon_warning_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/logos/
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/logos/build-by-maven-black.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/logos/maven-feather.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/logos/build-by-maven-white.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/banner.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/h5.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/icon_error_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/icon_success_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/expanded.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/external.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/icon_info_sml.gif
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/logo_apache.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/bg.jpg
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/newwindow.png
# hadoop-3.3.3/share/doc/hadoop/hadoop-hdfs-nfs/images/h3.jpg

# %%
# !cp -r hadoop-3.3.3/ /usr/local/

# %%
# !readlink -f /usr/bin/java | sed "s:bin/java::"
# Out:
# /usr/lib/jvm/java-11-openjdk-amd64/

# %%
import os
os.environ['JAVA_HOME'] = '/usr/lib/jvm/java-11-openjdk-amd64/'

# %%
# !/usr/local/hadoop-3.3.3/bin/hadoop
# Out:
# Usage: hadoop [OPTIONS] SUBCOMMAND [SUBCOMMAND OPTIONS]
#  or    hadoop [OPTIONS] CLASSNAME [CLASSNAME OPTIONS]
#   where CLASSNAME is a user-provided Java class
#
#   OPTIONS is none or any of:
#
# --config dir                     Hadoop config directory
# --debug                          turn on shell script debug mode
# --help                           usage information
# buildpaths                       attempt to add class files from build tree
# hostnames list[,of,host,names]   hosts to use in slave mode
# hosts filename                   list of hosts to use in slave mode
# loglevel level                   set the log4j level for this command
# workers                          turn on worker mode
#
#   SUBCOMMAND is one of:
#
#
#     Admin Commands:
#
# daemonlog     get/set the log level for each daemon
#
#     Client Commands:
#
# archive       create a Hadoop archive
# checknative   check native Hadoop and compression libraries availability
# classpath     prints the class path needed to get the Hadoop jar and the
#               required libraries
# conftest      validate configuration XML files
# credential    interact with credential providers
# distch        distributed metadata changer
# distcp        copy file or directories recursively
# dtutil        operations related to delegation tokens
# envvars       display computed Hadoop environment variables
# fs            run a generic filesystem user client
# gridmix       submit a mix of synthetic job, modeling a profiled from
#               production load
# jar <jar>     run a jar file. NOTE: please use "yarn jar" to launch YARN
#               applications, not this command.
# jnipath       prints the java.library.path
# kdiag         Diagnose Kerberos Problems
# kerbname      show auth_to_local principal conversion
# key           manage keys via the KeyProvider
# rumenfolder   scale a rumen input trace
# rumentrace    convert logs into a rumen trace
# s3guard       manage metadata on S3
# trace         view and modify Hadoop tracing settings
# version       print the version
#
#     Daemon Commands:
#
# kms           run KMS, the Key Management Server
# registrydns   run the registry DNS server
#
# SUBCOMMAND may print help when invoked w/o parameters or with -h.

# %%
# !/usr/local/hadoop-3.3.3/bin/hadoop version
# Out:
# Hadoop 3.3.3
# Source code repository https://github.com/apache/hadoop.git -r d37586cbda38c338d9fe481addda5a05fb516f71
# Compiled by stevel on 2022-05-09T16:36Z
# Compiled with protoc 3.7.1
# From source with checksum eb96dd4a797b6989ae0cdb9db6efc6
# This command was run using /usr/local/hadoop-3.3.3/share/hadoop/common/hadoop-common-3.3.3.jar

# %%
# !/usr/local/hadoop-3.3.3/bin/hdfs dfs -ls /
# Out:
# Found 29 items
# -rwxr-xr-x   1 root root          0 2023-10-30 16:55 /.dockerenv
# drwxr-xr-x   - root root       4096 2023-09-05 17:29 /.jupyter
# -rw-r--r--   1 root root        523 2023-09-05 17:29 /=2.*
# -rw-r--r--   1 root root      12831 2023-09-05 17:13 /=2023.0.1
# drwxr-xr-x   - root root       4096 2023-09-05 17:28 /bin
# drwxr-xr-x   - root root       4096 2020-04-15 11:09 /boot
# drwxr-xr-x   - root root        340 2023-10-30 16:55 /dev
# -rwxr-xr-x   1 root root        219 2023-06-26 03:34 /entrypoint.sh
# drwxr-xr-x   - root root       4096 2023-10-30 16:55 /etc
# drwxr-xr-x   - root root       4096 2023-06-26 03:52 /home
# -rwxr-xr-x   1 root root       1084 2023-06-26 03:34 /install_packages.sh
# drwxr-xr-x   - root root       4096 2023-10-30 16:55 /kaggle
# drwxr-xr-x   - root root       4096 2023-09-05 17:20 /lib
# drwxr-xr-x   - root root       4096 2023-06-05 14:03 /lib32
# drwxr-xr-x   - root root       4096 2023-06-05 14:05 /lib64
# drwxr-xr-x   - root root       4096 2023-06-05 14:03 /libx32
# drwxr-xr-x   - root root       4096 2023-06-05 14:03 /media
# drwxr-xr-x   - root root       4096 2023-06-05 14:03 /mnt
# drwxr-xr-x   - root root       4096 2023-09-05 17:18 /opt
# dr-xr-xr-x   - root root          0 2023-10-30 16:55 /proc
# drwx------   - root root       4096 2023-10-30 16:55 /root
# drwxr-xr-x   - root root       4096 2023-06-26 03:51 /run
# -rwxr-xr-x   1 root root        420 2023-06-26 03:34 /run_jupyter.sh
# drwxr-xr-x   - root root       4096 2023-09-05 17:20 /sbin
# drwxr-xr-x   - root root       4096 2023-06-05 14:03 /srv
# dr-xr-xr-x   - root root          0 2023-10-30 16:55 /sys
# drwxrwxrwt   - root root       4096 2023-10-30 17:03 /tmp
# drwxr-xr-x   - root root       4096 2023-06-26 04:54 /usr
# drwxr-xr-x   - root root       4096 2023-06-05 14:06 /var

# %%
# !/usr/local/hadoop-3.3.3/bin/hdfs dfs -df /
# Out:
# Filesystem           Size           Used      Available  Use%
# file:///    8656922775552  5388028657664  3268894117888   62%

# %%
# !/usr/local/hadoop-3.3.3/bin/hdfs dfs -mkdir /hadoop

# %%
# !/usr/local/hadoop-3.3.3/bin/hdfs dfs -rm -r /hadoop
# Out:
# 2023-10-30 17:03:33,067 INFO Configuration.deprecation: io.bytes.per.checksum is deprecated. Instead, use dfs.bytes-per-checksum
# Deleted /hadoop

# %% [markdown]
# ### Hadoop Streaming

# %%
# !find / -name 'hadoop-streaming*.jar'
# Out:
# /usr/local/hadoop-3.3.3/share/hadoop/tools/sources/hadoop-streaming-3.3.3-sources.jar
# /usr/local/hadoop-3.3.3/share/hadoop/tools/sources/hadoop-streaming-3.3.3-test-sources.jar
# /usr/local/hadoop-3.3.3/share/hadoop/tools/lib/hadoop-streaming-3.3.3.jar
# /kaggle/working/hadoop-3.3.3/share/hadoop/tools/sources/hadoop-streaming-3.3.3-test-sources.jar
# /kaggle/working/hadoop-3.3.3/share/hadoop/tools/sources/hadoop-streaming-3.3.3-sources.jar
# /kaggle/working/hadoop-3.3.3/share/hadoop/tools/lib/hadoop-streaming-3.3.3.jar

# %% [markdown]
# ### Write the mapper and reducer files

# %%
# %%writefile mapper.py
import sys
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import pickle
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,OneHotEncoder,OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from catboost import CatBoostRegressor
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import joblib

rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

X = []  
y = []

first_line = True
X_data = []  
y_data = []  
for line in sys.stdin:
    data = line.strip().split(',')
    
    if first_line:
        first_line = False
        continue
    try:
        features = data[:-1]
        label = data[-1]
    except Exception as e:
        continue
    X_data.append(features)
    y_data.append(label)
X_columns = ['content_rating', 'tomatometer_status', 'audience_status', 'runtime',
       'tomatometer_count', 'audience_rating', 'audience_count',
       'tomatometer_top_critics_count', 'tomatometer_fresh_critics_count',
       'tomatometer_rotten_critics_count', ' Animation', ' Anime & Manga',
       ' Art House & International', ' Classics', ' Comedy', ' Cult Movies',
       ' Documentary', ' Drama', ' Faith & Spirituality', ' Gay & Lesbian',
       ' Horror', ' Kids & Family', ' Musical & Performing Arts',
       ' Mystery & Suspense', ' Romance', ' Science Fiction & Fantasy',
       ' Special Interest', ' Sports & Fitness', ' Television', ' Western',
       'Action & Adventure', 'Animation', 'Art House & International',
       'Classics', 'Comedy', 'Cult Movies', 'Documentary', 'Drama', 'Horror',
       'Kids & Family', 'Musical & Performing Arts', 'Mystery & Suspense',
       'Romance', 'Science Fiction & Fantasy', 'Special Interest',
       'Television', 'Western']

X = pd.DataFrame(X_data, columns=X_columns)
y = pd.DataFrame(y_data, columns=['tomatometer_rating'])
numerical_columns = [
    'runtime', 'tomatometer_count', 'audience_rating',
    'audience_count', 'tomatometer_top_critics_count',
    'tomatometer_fresh_critics_count', 'tomatometer_rotten_critics_count'
]

X[numerical_columns] = X[numerical_columns].astype(float)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)
X_test.to_csv('test.csv', index=False)
x_cont_col = list(X.describe())
x_cat_col = list(c for c in X.columns if c not in x_cont_col)
x_train_cont_data = X_train.loc[:, x_cont_col]
x_train_cat_data = X_train.loc[:, x_cat_col]
x_test_cont_data = X_test.loc[:, x_cont_col]
x_test_cat_data = X_test.loc[:, x_cat_col]

sc = StandardScaler()
y_train = sc.fit_transform(y_train)
y_test = sc.transform(y_test)
cont_transform = Pipeline(steps=[('scaler', StandardScaler())])
cat_transform = Pipeline(steps=[('onehot', OneHotEncoder(handle_unknown='ignore',sparse=False))])
ct = ColumnTransformer(
    transformers=[
        ('num', cont_transform, x_cont_col),
        ('cat', cat_transform, x_cat_col)],
        remainder='passthrough')
x_train = pd.concat([x_train_cont_data, x_train_cat_data], axis=1)
x_test = pd.concat([x_test_cont_data, x_test_cat_data], axis=1)
xt_train = ct.fit_transform(x_train)
xt_test = ct.transform(x_test)
file_name = 'label_array.npy'
np.save(file_name, y_train)
rf = RandomForestRegressor()
rf.fit(xt_train,y_train)

with open('RF_model.pkl', 'wb') as model_file:
    pickle.dump(rf, model_file)
    
joblib.dump(sc, 'LabelEncoder.pkl')

for i in range(len(y_test)):
    print(f"{','.join(map(str, xt_test[i]))},{y_test[i][0]}")
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py
import sys
import pickle
from sklearn.metrics import accuracy_score, classification_report
import sys
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import pickle
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,OneHotEncoder,OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from catboost import CatBoostRegressor
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

with open('RF_model.pkl', 'rb') as model_file:
    rf = pickle.load(model_file)

first_line = True
X_data = []  # Initialize a list to store the features
y_data = []  # Initialize a list to store the labels

for line in sys.stdin:
    data = line.strip().split(',')
    
    if first_line:
        first_line = False
        continue
    try:
        features = data[:-1]
        label = data[-1]
    except Exception as e:
        continue

    X_data.append(features)
    y_data.append(label)

X_test = X_data
y_test = y_data
y_pred = rf.predict(X_test)
y_test = np.array(y_test).astype(float)  # Convert y_test to a numeric array
y_pred = y_pred.astype(float)
y_pred = y_pred.reshape(-1,1)
r1 = r2_score(y_test,y_pred)
print("Random Forest r2: ", r1)
with open('RF_model.pkl', 'wb') as model_file:
    pickle.dump(rf, model_file)
# Out:
# Overwriting reducer.py

# %%
# !chmod u+rwx /kaggle/working/mapper.py
# !chmod u+rwx /kaggle/working/reducer.py

# %%
# !/usr/local/hadoop-3.3.3/bin/hadoop jar /usr/local/hadoop-3.3.3/share/hadoop/tools/lib/hadoop-streaming-3.3.3.jar -input /kaggle/working/your_data.csv -output /kaggle/working/output1 -file /kaggle/working/mapper.py  -file /kaggle/working/reducer.py  -mapper 'python mapper.py'  -reducer 'python reducer.py'

# %%
# !cat /kaggle/working/bda.csv | python mapper.py | python reducer.py 2>&1
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /kaggle/working/mapper.py:111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(xt_train,y_train)
# Random Forest r2:  0.9975076195604055

# %% [markdown]
# Random Forest r2:  0.9975076195604055

# %% [markdown]
# RF_model.pkl and LabelEncoder.pkl are saved to host flask model. server.py have the flask deployment , the data is being displayed using postman api requests
